# %% [markdown]
# # 1 Modules

# %%
#Good references
#  https://pandas.pydata.org/docs/reference/frame.html
# https://pandas.pydata.org/docs/pandas.pdf

# %% [markdown]
# ## 1.1 Sub-modules

# %%
message1 = "hello"
message2 = "world"

# %%
print(f'{message1} narh {message2}')
# Out:
# daniel narh treku

# %%
countries =['United States', 'India', 'China', 'Brazil']

# %%
countries
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
countries[-2]
# Out:
# 'China'

# %%
countries[1:2]
# Out:
# ['India']

# %%
countries.append("Canada")

# %%
countries
# Out:
# ['United States', 'India', 'China', 'Brazil', 'Canada']

# %%
countries.insert(0,"Spain")

# %%
countries
# Out:
# ['Spain', 'United States', 'India', 'China', 'Brazil', 'Canada']

# %%
countries_2 =["UK", "Germany", "Austria"]

# %%
countries + countries_2
# Out:
# ['Spain',
#  'United States',
#  'India',
#  'China',
#  'Brazil',
#  'Canada',
#  'UK',
#  'Germany',
#  'Austria']

# %%
nested_list = [countries, countries_2]

# %%
nested_list
# Out:
# [['Spain', 'United States', 'India', 'China', 'Brazil', 'Canada'],
#  ['UK', 'Germany', 'Austria']]

# %%
countries =['United States', 'India', 'China', 'Brazil']

# %%
countries.remove("United States")

# %%
countries
# Out:
# ['India', 'China', 'Brazil']

# %%
countries
# Out:
# ['Spain', 'United States', 'India', 'China', 'Brazil', 'Canada']

# %%
countries.pop(-1)
# Out:
# 'Canada'

# %%
countries
# Out:
# ['Spain', 'United States', 'India', 'China', 'Brazil']

# %%
del countries[0]

# %%
countries
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
numbers = [4,3,10,7,1,2]

# %%
numbers.sort()

# %%
numbers
# Out:
# [1, 2, 3, 4, 7, 10]

# %%
numbers.sort(reverse=True)

# %%
numbers
# Out:
# [10, 7, 4, 3, 2, 1]

# %%
numbers[0] = 1000
numbers
# Out:
# [1000, 7, 4, 3, 2, 1]

# %%
countries[:]
new_list = countries[:]

# %%
new_list
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
new_list_2 = countries.copy()

# %%
new_list_2
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
my_dict = {'key1':'value1', 'key2':'value2'}

# %%
my_data = {'name':'Daniel', 'age':26}

# %%
my_data.keys() #access dictionary keys
# Out:
# dict_keys(['name', 'age'])

# %%
my_data.values() #access dict values
# Out:
# dict_values(['Daniel', 26])

# %%
my_data.items() #access dict items
# Out:
# dict_items([('name', 'Daniel'), ('age', 26)])

# %%
my_data['height'] = 1.7  #add an item to dict

# %%
my_data
# Out:
# {'name': 'Daniel', 'age': 26, 'height': 1.7}

# %%
my_data.update({'height': 1.95})  #update the value of a key

# %%
my_data
# Out:
# {'name': 'Daniel', 'age': 26, 'height': 1.95}

# %%
new_dict = my_data.copy() # make a copy of dict -  works independently of old dictionary

# %%
new_dict
# Out:
# {'name': 'Daniel', 'age': 26, 'height': 1.95}

# %%
my_dict_2 = my_data # make a copy of dict - works dependent on old dictionary changes

# %%
my_dict_2
# Out:
# {'name': 'Daniel', 'age': 26, 'height': 1.95}

# %%
my_data.pop('name') # remove item from dict
# Out:
# 'Daniel'

# %%
my_data
# Out:
# {'age': 26, 'height': 1.95}

# %%
del my_data['age']  #delete or remove an item from dict

# %%
my_data
# Out:
# {'height': 1.95}

# %%
my_data.clear() #removes all item in the dictionary

# %%
my_data
# Out:
# {}

# %% [markdown]
# ## IF Statement

# %%
age = 20

if age >=18:
    print("You're an adult!")
elif age>=13:
    print("You're a teenager")
else:
    print("You're a kid!")
# Out:
# You're an adult!

# %% [markdown]
# ## For loop

# %%
countries =['United States', 'India', 'China', 'Brazil']

for country in countries:
    print(country)
# Out:
# United States
# India
# China
# Brazil

# %%
for i, country in enumerate(countries):
    print(i)
    print(country)
# Out:
# 0
# United States
# 1
# India
# 2
# China
# 3
# Brazil

# %%
my_data = {'name':'Daniel', 'age':26}
for key, value in my_data.items():
    print(key)
    print(value)
# Out:
# name
# Daniel
# age
# 26

# %% [markdown]
# ## Function

# %%
def sum_values(a, b): 
    x=a+b
    return x

# %%
sum_values(1,3)
# Out:
# 4

# %% [markdown]
# ### Built-in functions

# %%
countries =['United States', 'India', 'China', 'Brazil']

# %%
len(countries)
# Out:
# 4

# %%
max([10, 63, 81, 99])
# Out:
# 99

# %%
min([10, 63, 81, 99])
# Out:
# 10

# %%
type(countries)
# Out:
# list

# %%
range(1, 10, 2)
# Out:
# range(1, 10, 2)

# %%
for i in range (1, 10, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# ## Modules

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\niina\\OneDrive - The University of Texas-Rio Grande Valley\\dissertation folder\\Essay 3\\2022'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'BitcoinCryptoSentiment.ipynb',
#  'CryptoResearchDataAnalysis.ipynb',
#  'DataAnalysisLearningPython.ipynb',
#  'dataBitcoin2020.csv',
#  'dataBitcoin2020a.csv',
#  'DataForLearning',
#  'EthereumCryptoSentiment.ipynb']

# %%
os.makedirs("New Folder")

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'BitcoinCryptoSentiment.ipynb',
#  'CryptoDataAnalysis.ipynb',
#  'DataAnalysisPython.ipynb',
#  'EthereumCryptoSentiment.ipynb',
#  'New Folder']

# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np
import os.path

# %%
#creating an array
data = np.array([[1,4],[2,5],[3,6]])

data
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
#creating a dataframe with pandas
df = pd.DataFrame(data)
df
# Out:
#    0  1
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df = pd.DataFrame(data, index=['row1', 'row2', 'row3'], columns =['col1', 'col2'])

# %%
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %%
# creating an array with list shape
data2 = ([[1,4],[2,5],[3,6]])

# %%
df2 = pd.DataFrame(data2, index=['row1', 'row2', 'row3'], columns =['col1', 'col2'])

# %%
df2
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %%
#creating a DataFrame from a dictionary
states =["California", "Texas", "Florida", "New York"]
population = [39613493, 29730311, 21944577, 19299981]

# %%
dict_states_pop ={'States':states, 'Population':population}

# %%
df_population_data = pd.DataFrame(dict_states_pop)

# %%
df_population_data
# Out:
#        States  Population
# 0  California    39613493
# 1       Texas    29730311
# 2     Florida    21944577
# 3    New York    19299981

# %%
#creating from a csv file
df_exams = pd.read_csv('DataForLearning/StudentsPerformance.csv')

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_exams.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df_exams.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
df_exams.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# ...

# %%
df_exams.shape
# Out:
# (1000, 8)

# %%
pd.set_option('display.max_rows', 1000) #to display

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %% [markdown]
# # DataFrame Attributes

# %%
df_exams.shape
# Out:
# (1000, 8)

# %%
df_exams.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df_exams.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df_exams.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# # DataFrame Methods

# %%
df_exams.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# # Functions

# %%
len(df_exams)
# Out:
# 1000

# %%
max(df_exams.index)
# Out:
# 999

# %%
min(df_exams.index)
# Out:
# 0

# %%
type(df_exams)
# Out:
# pandas.core.frame.DataFrame

# %%
round(df_exams,2).head(12)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
#
#    test preparation course  math score  reading score  writing score  \
# ...

# %%
#Selecting column

# %%
df_exams[['gender']].head(8)  #This comes out as a DataFrame
# Out:
#    gender
# 0  female
# 1  female
# 2  female
# 3    male
# 4    male
# 5  female
# 6  female
# 7    male

# %%
df_exams['gender'].head(8)  #this comes out as series
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# 5    female
# 6    female
# 7      male
# Name: gender, dtype: object

# %%
type(df_exams['gender'])
# Out:
# pandas.core.series.Series

# %%
df_exams['gender'].index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df_exams['gender'].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %%
#Second syntax to select a column

# %%
df_exams.gender.head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %%
df_exams['math score'].head()
# Out:
# 0    72
# 1    69
# 2    90
# 3    47
# 4    76
# Name: math score, dtype: int64

# %%
#Selecting two or more column

# %%
df_exams[['gender', 'math score']].head()
# Out:
#    gender  math score
# 0  female          72
# 1  female          69
# 2  female          90
# 3    male          47
# 4    male          76

# %%
type(df_exams[['gender', 'math score']])
# Out:
# pandas.core.frame.DataFrame

# %%
df_exams[['gender', 'writing score', 'math score','reading score']].head()
# Out:
#    gender  writing score  math score  reading score
# 0  female             74          72             72
# 1  female             88          69             90
# 2  female             93          90             95
# 3    male             44          47             57
# 4    male             75          76             78

# %% [markdown]
# # Adding new columns to DataFrame

# %% [markdown]
# ### Adding with a scaler(single) value

# %%
df_exams['language score'] = 70

# %%
df_exams.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    language score
# 0              70
# 1              70
# 2              70
# 3              70
# 4              70

# %% [markdown]
# ### Adding a new column using arrays (numpy)

# %%
#import numpy and create an array of 100 elements
import numpy as np

# %%
len(np.arange(0, 1000))
# Out:
# 1000

# %%
language_score = (np.arange(0, 1000))

# %%
 len(language_score)
# Out:
# 1000

# %%
#add column with the array

# %%
df_exams['language score'] = language_score

# %%
df_exams.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    language score
# 0               0
# 1               1
# 2               2
# 3               3
# 4               4

# %%
df_exams.tail(5)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 995             995
# 996             996
# 997             997
# 998             998
# 999             999

# %%
#create random integer numbers between 1 and 100
np.random.randint(1, 100, size=1000)
int_language_score = np.random.randint(1, 100, size=1000)

# %%
min(int_language_score )
# Out:
# 1

# %%
max(int_language_score )
# Out:
# 99

# %%
df_exams['anguage_score'] = int_language_score

# %%
df_exams.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    language score  anguage_score
# 0               0              2
# 1               1             21
# 2               2             50
# ...

# %%
#dropping a column from DataFrame
#DataFrame.drop(labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise')
#df_exams.drop(['A',B'], axis=1)
df_exams.drop(['language score'], axis=1)  #axis 1 for dropping columns or using 'columns = []', 0 for index or rows
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
#Alternative for dropping columns
df_exams.drop(columns=['language score'])
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
#dropping a row from DataFrame by index
df.drop([0, 1])  #This will drop the first two rows in our DataFrame.

# %%
#renaming one or more columns
#df = df.rename(columns={'oldName1': 'newName1', 'oldName2': 'newName2'}) 
df_exams.rename(columns={'anguage_score': 'language_scores'})
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
df_exams = df_exams.drop(columns=['language score'])

# %%
df_exams = df_exams.rename(columns={'anguage_score': 'language_score'})

# %%
#create random float numbers between 1 and 100
float_language_score=np.random.uniform(1,100, size=1000)

# %%
float_language_score
# Out:
# array([ 4.79599256,  8.9552529 , 53.98516534, 51.68183179, 87.92781218,
#         3.73986669, 84.22242428, 40.52297916, 37.12275705, 40.70754466,
#        55.63643947, 17.95219845, 23.95900457,  8.24868816,  8.27322974,
#        78.27462246, 24.95725003, 93.24344825, 33.88419752, 22.83579458,
#        96.12125333, 76.35880914, 92.9554665 , 11.10934586, 30.84055193,
#        74.65857301, 77.84931785, 88.78700165, 92.24175926, 94.72974752,
#        15.41561163,  5.57602496, 58.11329711, 29.62252029, 89.80315109,
#        62.11084161, 65.27893335, 32.13142886, 16.83469641, 74.50237044,
#         9.76766379, 19.37301849, 92.68309375,  7.91087147, 10.71305287,
#        92.51300322, 95.08296104, 56.72228001, 46.22323794,  4.51577054,
#        27.46134274, 44.74415286, 41.46755321, 14.30943424, 50.19126972,
#        47.38268165, 68.83596182, 99.57817535, 13.00075008, 34.62221085,
#        95.44531111, 67.78967098, 36.99272832, 59.7562588 , 50.79578626,
# ...

# %%
len(pd.DataFrame(float_language_score))
# Out:
# 1000

# %% [markdown]
# ## Bonus -- More on creating DataFrames, floats and int

# %%
df = pd.DataFrame(np.arange(12).reshape(3, 4),
                  columns=['A', 'B', 'C', 'D'])         
print(df)
# Out:
#    A  B   C   D
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
df2 = pd.DataFrame(np.random.randint(12, size = 100).reshape(20, 5),
                  columns=['A', 'B', 'C', 'D', 'E'])
print(df2)
# Out:
#      A   B   C   D   E
# 0    5   0  10   5   3
# 1   11   7  11   6   7
# 2    1  11   6   4   1
# 3   10   9   7  10   7
# 4    9  10   3   9   4
# 5   10   9   8   8  11
# 6    7   4   7   5   7
# 7    9   0   5   3  10
# 8    6   8   9  10   0
# 9    4   1   5   7   8
# 10   9   6   5  11   4
# 11   7   2  10  10   0
# 12   6   5   5   0   4
# 13   5   5   1  10  10
# 14   8   9   5  10   5
# 15  11   3   6   3   8
# 16   2   8   1   5   5
# 17   3   2   1   1  10
# 18   3   7  10  11   0
# 19  10   2   2   1   4

# %%
df3 = pd.DataFrame(np.random.uniform(5,30, size=50).reshape(10,5), columns=['A', 'B', 'C','D','E'])
print(df3)
# Out:
#            A          B          C          D          E
# 0  24.933621   9.651901  29.548186  22.676200  14.623946
# 1  26.367799   8.925658  20.165797   5.431659  18.163302
# 2  14.471176   8.865142  12.275974  27.013939  29.870601
# 3   9.275805   8.423726  21.673818  15.037724  11.198689
# 4  14.088592   7.117788  29.993815   6.243002  17.784487
# 5  15.858237   6.395899  24.065644  15.825325  22.513099
# 6  17.010309  18.803489  16.732717  19.568237  22.200497
# 7  23.285794  28.909128   8.510141  13.609954  27.864075
# 8  16.034604   6.764849  21.048927  13.768299  29.050969
# 9  15.257688  29.557946  10.966622  14.339893  15.898374

# %%
print(round(df3,2))
# Out:
#        A      B      C      D      E
# 0  24.93   9.65  29.55  22.68  14.62
# 1  26.37   8.93  20.17   5.43  18.16
# 2  14.47   8.87  12.28  27.01  29.87
# 3   9.28   8.42  21.67  15.04  11.20
# 4  14.09   7.12  29.99   6.24  17.78
# 5  15.86   6.40  24.07  15.83  22.51
# 6  17.01  18.80  16.73  19.57  22.20
# 7  23.29  28.91   8.51  13.61  27.86
# 8  16.03   6.76  21.05  13.77  29.05
# 9  15.26  29.56  10.97  14.34  15.90

# %% [markdown]
# ## Bonus -- Drop columns and/or rows of MultiIndex DataFrame

# %%
midx = pd.MultiIndex(levels=[['lama', 'cow', 'falcon'],
                             ['speed', 'weight', 'length']],
                     codes=[[0, 0, 0, 1, 1, 1, 2, 2, 2],
                            [0, 1, 2, 0, 1, 2, 0, 1, 2]])

midx
# Out:
# MultiIndex([(  'lama',  'speed'),
#             (  'lama', 'weight'),
#             (  'lama', 'length'),
#             (   'cow',  'speed'),
#             (   'cow', 'weight'),
#             (   'cow', 'length'),
#             ('falcon',  'speed'),
#             ('falcon', 'weight'),
#             ('falcon', 'length')],
#            )

# %%
df = pd.DataFrame(index=midx, columns=['big', 'small'],
                  data=[[45, 30], [200, 100], [1.5, 1], [30, 20],
                        [250, 150], [1.5, 0.8], [320, 250],
                        [1, 0.8], [0.3, 0.2]])
df
# Out:
#                  big  small
# lama   speed    45.0   30.0
#        weight  200.0  100.0
#        length    1.5    1.0
# cow    speed    30.0   20.0
#        weight  250.0  150.0
#        length    1.5    0.8
# falcon speed   320.0  250.0
#        weight    1.0    0.8
#        length    0.3    0.2

# %%
df.drop(index='cow', columns='small')
# Out:
#                  big
# lama   speed    45.0
#        weight  200.0
#        length    1.5
# falcon speed   320.0
#        weight    1.0
#        length    0.3

# %%
df.drop(index='length', level=1)
# Out:
#                  big  small
# lama   speed    45.0   30.0
#        weight  200.0  100.0
# cow    speed    30.0   20.0
#        weight  250.0  150.0
# falcon speed   320.0  250.0
#        weight    1.0    0.8

# %% [markdown]
# # 1 Math Operations
# ### Back to df_exams DataFrame

# %% [markdown]
# ## 1.1 Operations in columns

# %%
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    language_score
# 0               2
# 1              21
# 2              50
# 3              25
# 4              91

# %%
# select a column and calculate total sum
df_exams['math score'].sum()
# Out:
# 66089

# %%
#count, mean, std, max, min

# %%
df_exams['math score'].count()
# Out:
# 1000

# %%
df_exams['math score'].mean()
# Out:
# 66.089

# %%
df_exams['math score'].std()
# Out:
# 15.163080096009468

# %%
df_exams['math score'].max()
# Out:
# 100

# %%
df_exams['math score'].min()
# Out:
# 0

# %%
#More efficient - easier using the describe method #it does it on all numerical columns
df_exams.describe()
# Out:
#        math score  reading score  writing score  language_score
# count  1000.00000    1000.000000    1000.000000     1000.000000
# mean     66.08900      69.169000      68.054000       50.517000
# std      15.16308      14.600192      15.195657       28.731188
# min       0.00000      17.000000      10.000000        1.000000
# 25%      57.00000      59.000000      57.750000       26.000000
# 50%      66.00000      70.000000      69.000000       50.500000
# 75%      77.00000      79.000000      79.000000       75.000000
# max     100.00000     100.000000     100.000000       99.000000

# %% [markdown]
# ## 1.2 Operations in rows

# %%
# calculating the sum in a row

# %%
df_exams['math score'] + df_exams['reading score'] + df_exams['writing score']
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
# 5      232
# 6      275
# 7      122
# 8      195
# 9      148
# 10     164
# 11     135
# 12     219
# 13     220
# 14     161
# 15     222
# 16     263
# 17      78
# 18     134
# 19     173
# 20     198
# 21     210
# 22     151
# 23     215
# 24     225
# 25     219
# 26     178
# 27     211
# 28     205
# 29     207
# 30     217
# 31     189
# 32     193
# 33     120
# 34     266
# 35     241
# 36     238
# 37     173
# 38     253
# 39     170
# 40     170
# 41     199
# 42     176
# 43     190
# 44     160
# 45     176
# 46     182
# 47     213
# 48     207
# 49     248
# 50     156
# 51     214
# 52     139
# 53     241
# 54     242
# 55     117
# 56     253
# 57     156
# 58     175
# 59      27
# 60     225
# 61     112
# 62     178
# 63     220
# 64     176
# 65     192
# 66     119
# 67     206
# 68     175
# 69     160
# 70     194
# 71     181
# 72     140
# 73     174
# 74     139
# 75     123
# ...

# %%
# calculating the average score and assigning the result to a new column
df_exams['avg'] = (df_exams['math score'] + df_exams['reading score'] + df_exams['writing score'])/3

# %%
#showing the dataframe
df_exams.head()
df_exams.round(2).head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    language_score    avg
# 0               2  72.67
# 1              21  82.33
# 2              50  92.67
# 3              25  49.33
# ...

# %% [markdown]
# # 1 Value Counts

# %%
#counting gender elements
#len function
len(df_exams['gender'])
# Out:
# 1000

# %%
# .count method
df_exams['gender'].count()
# Out:
# 1000

# %%
# counting gender elements by category
df_exams['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
#return the relative frequency (divide all values by the sum of values)
df_exams['gender'].value_counts(normalize = True)
# Out:
# female    0.518
# male      0.482
# Name: gender, dtype: float64

# %%
#counting "parental level of education" elements by category
print(df_exams['parental level of education'].value_counts())
df_exams['parental level of education'].value_counts(normalize = True)
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64
# some college          0.226
# associate's degree    0.222
# high school           0.196
# some high school      0.179
# bachelor's degree     0.118
# master's degree       0.059
# Name: parental level of education, dtype: float64
